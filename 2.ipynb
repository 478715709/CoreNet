# %%
from google.colab import drive
drive.mount('/content/drive')
print("Google Drive mounted successfully!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Drive mounted successfully!

# %%
import os
import random
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve, auc
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical
import gym
from gym import spaces
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.font_manager import FontProperties

# 设置中文字体，避免中文显示为方块
font = FontProperties(fname=r"C:\Windows\Fonts\simhei.ttf", size=12)
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# ----------------------------
DATA_DIR = r'/content/drive/MyDrive/1/dataset/dataset/train'
METADATA_PATH = r'/content/drive/MyDrive/1/metadata.csv'
FEATURES = ['ton', 'thrust', 'mfr']
WINDOW_SIZE = 10
TARGET_LENGTH = 1000  # 采样后序列长度，确保 >= WINDOW_SIZE
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {DEVICE}")

# ----------------------------
metadata = pd.read_csv(METADATA_PATH)

# ----------------------------
def uniform_downsample(X, y, target_length):
    length = X.shape[0]
    if length <= target_length:
        return X, y
    interval = length / target_length
    indices = (np.floor(np.arange(target_length) * interval)).astype(int)
    indices = np.clip(indices, 0, length - 1)
    return X[indices], y[indices]

# ----------------------------
all_files = metadata['filename'].values.tolist()
sampled_files = all_files
print(f"Using all {len(sampled_files)} files for training/testing.")

# ----------------------------
data_dict = {}
for f in sampled_files:
    file_path = os.path.join(DATA_DIR, f)
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        # 将所有非0异常标签统一为1，实现二分类
        if 'anomaly_code' not in df.columns:
            df['anomaly_code'] = 0
        else:
            df['anomaly_code'] = df['anomaly_code'].fillna(0).astype(int)
            df['anomaly_code'] = df['anomaly_code'].apply(lambda x: 0 if x == 0 else 1)
        data_dict[f] = df
    else:
        print(f"Warning: file {f} not found in data directory.")

# ----------------------------
normal_files = [f for f in sampled_files if metadata.loc[metadata['filename'] == f, 'anomaly_code'].values[0] == 0]
all_normal_data = []
for f in normal_files:
    all_normal_data.append(data_dict[f][FEATURES].values)
all_normal_data = np.vstack(all_normal_data)
scaler = StandardScaler()
scaler.fit(all_normal_data)

# ----------------------------
def preprocess(df):
    X = df[FEATURES].values
    X = scaler.transform(X)
    y = df['anomaly_code'].values
    return X, y

# ----------------------------
class AnomalyDetectionEnv(gym.Env):
    def __init__(self, data, labels, window_size=WINDOW_SIZE):
        super().__init__()
        self.data = data.astype(np.float32)
        self.labels = labels.astype(np.int64)
        self.window_size = window_size
        self.feature_dim = data.shape[1]
        self.T = data.shape[0]
        self.current_step = 0

        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(window_size, self.feature_dim), dtype=np.float32)
        self.action_space = spaces.Discrete(2)  # 0正常，1异常

    def reset(self):
        self.current_step = self.window_size - 1
        return self._get_state()

    def _get_state(self):
        return self.data[self.current_step - self.window_size + 1:self.current_step + 1]

    def step(self, action):
        true_label = self.labels[self.current_step]
        done = False

        if action == true_label:
            reward = 1.0 if action == 1 else 0.5
        else:
            reward = -1.0 if true_label == 1 else -0.5

        self.current_step += 1
        if self.current_step >= self.T - 1:
            done = True

        next_state = self._get_state() if not done else np.zeros((self.window_size, self.feature_dim), dtype=np.float32)
        return next_state, reward, done, {}

# ----------------------------
class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, hidden_dim, window_size):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, 2)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = out[:, -1, :]
        logits = self.fc(out)
        return logits

# ----------------------------
class PPOAgent:
    def __init__(self, policy_net, lr=3e-4, gamma=0.99, eps_clip=0.2):
        self.policy_net = policy_net.to(DEVICE)
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)
        self.gamma = gamma
        self.eps_clip = eps_clip

    def select_action(self, state):
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(DEVICE)
        logits = self.policy_net(state)
        probs = torch.softmax(logits, dim=-1)
        dist = Categorical(probs)
        action = dist.sample()
        return action.item(), dist.log_prob(action), probs[0,1].item()

    def compute_returns(self, rewards, dones):
        returns = []
        R = 0
        for r, done in zip(reversed(rewards), reversed(dones)):
            if done:
                R = 0
            R = r + self.gamma * R
            returns.insert(0, R)
        returns = torch.tensor(returns, dtype=torch.float32).to(DEVICE)
        return returns

    def update(self, states, actions, old_log_probs, returns):
        states = torch.stack(states).to(DEVICE)
        actions = torch.tensor(actions).to(DEVICE)
        old_log_probs = torch.stack(old_log_probs).to(DEVICE)
        returns = returns.detach()

        logits = self.policy_net(states)
        probs = torch.softmax(logits, dim=-1)
        dist = Categorical(probs)
        log_probs = dist.log_prob(actions)

        ratios = torch.exp(log_probs - old_log_probs)
        advantages = returns - returns.mean()

        surr1 = ratios * advantages
        surr2 = torch.clamp(ratios, 1 - self.eps_clip, 1 + self.eps_clip) * advantages

        loss = -torch.min(surr1, surr2).mean()

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# ----------------------------
train_sns = [f"SN{str(i).zfill(2)}" for i in range(1,13)]
test_sns = [f"SN{str(i).zfill(2)}" for i in range(13,25)]

train_data_list, train_label_list = [], []
test_data_list, test_label_list = [], []

for f in sampled_files:
    sn = None
    for s in train_sns:
        if s in f:
            sn = s
            break
    if sn is not None:
        X, y = preprocess(data_dict[f])
        # 如果想用全部数据，不降采样，注释下一行
        X, y = uniform_downsample(X, y, TARGET_LENGTH)
        train_data_list.append(X)
        train_label_list.append(y)
    else:
        for s in test_sns:
            if s in f:
                sn = s
                break
        if sn is not None:
            X, y = preprocess(data_dict[f])
            # 如果想用全部数据，不降采样，注释下一行
            X, y = uniform_downsample(X, y, TARGET_LENGTH)
            test_data_list.append(X)
            test_label_list.append(y)

train_data = np.vstack(train_data_list)
train_labels = np.concatenate(train_label_list)
test_data = np.vstack(test_data_list)
test_labels = np.concatenate(test_label_list)

print(f"训练数据长度: {train_data.shape[0]}, 测试数据长度: {test_data.shape[0]}")

# ----------------------------
train_env = AnomalyDetectionEnv(train_data, train_labels, window_size=WINDOW_SIZE)
policy_net = PolicyNetwork(input_dim=len(FEATURES), hidden_dim=64, window_size=WINDOW_SIZE)
agent = PPOAgent(policy_net)

# ----------------------------
def train_ppo(env, agent, max_episodes=100, update_timestep=2000):
    timestep = 0
    memory = {'states': [], 'actions': [], 'log_probs': [], 'rewards': [], 'dones': []}

    for ep in range(max_episodes):
        state = env.reset()
        ep_reward = 0
        done = False

        while not done:
            with torch.no_grad():
                action, log_prob, _ = agent.select_action(state)

            memory['states'].append(torch.tensor(state, dtype=torch.float32))
            memory['actions'].append(action)
            memory['log_probs'].append(log_prob)

            next_state, reward, done, _ = env.step(action)
            memory['rewards'].append(reward)
            memory['dones'].append(done)

            state = next_state
            ep_reward += reward
            timestep += 1

            if timestep % update_timestep == 0 or done:
                returns = agent.compute_returns(memory['rewards'], memory['dones'])
                agent.update(memory['states'], memory['actions'], memory['log_probs'], returns)
                memory = {'states': [], 'actions': [], 'log_probs': [], 'rewards': [], 'dones': []}

        print(f"Episode {ep+1} Reward: {ep_reward:.2f}")

# ----------------------------
train_ppo(train_env, agent, max_episodes=50, update_timestep=1000)

# ----------------------------
def test_agent(agent, data_dict, test_files, window_size=WINDOW_SIZE, target_length=TARGET_LENGTH):
    all_preds = []
    all_true = []
    all_probs = []

    for f in test_files:
        X, y = preprocess(data_dict[f])
        # 如果想用全部数据，不降采样，注释下一行
        X, y = uniform_downsample(X, y, target_length)
        env = AnomalyDetectionEnv(X, y, window_size=window_size)
        state = env.reset()
        done = False
        preds = []
        probs = []
        while not done:
            action, _, prob = agent.select_action(state)
            preds.append(action)
            probs.append(prob)
            state, _, done, _ = env.step(action)
        all_preds.extend(preds)
        all_true.extend(y[window_size-1:window_size-1+len(preds)])
        all_probs.extend(probs)

    all_true = np.array(all_true)
    all_preds = np.array(all_preds)
    all_probs = np.array(all_probs)

    print("\n测试集分类报告:")
    print(classification_report(all_true, all_preds, digits=4))

    accuracy = accuracy_score(all_true, all_preds)
    precision = precision_score(all_true, all_preds, zero_division=0)
    recall = recall_score(all_true, all_preds, zero_division=0)
    f1 = f1_score(all_true, all_preds, zero_division=0)

    try:
        auc_roc = roc_auc_score(all_true, all_probs)
    except ValueError:
        auc_roc = float('nan')

    print(f"准确率 (Accuracy): {accuracy:.4f}")
    print(f"精确率 (Precision): {precision:.4f}")
    print(f"召回率 (Recall): {recall:.4f}")
    print(f"F1分数 (F1-score): {f1:.4f}")
    print(f"AUC-ROC: {auc_roc:.4f}")

    plot_time_series(all_true, all_preds, length=500)
    plot_confusion_matrix(all_true, all_preds)
    plot_roc_curve(all_true, all_probs)
    plot_precision_recall_curve(all_true, all_probs)

    return all_true, all_preds, all_probs

# ----------------------------
def plot_time_series(true_labels, pred_labels, length=500):
    plt.figure(figsize=(15,4))
    x = np.arange(length)
    plt.plot(x, true_labels[:length], label='真实异常标签', color='blue', marker='x', linestyle='-')
    plt.plot(x, pred_labels[:length], label='预测异常标签', color='red', marker='o', linestyle='--')
    plt.xlabel('时间步', fontproperties=font)
    plt.ylabel('异常状态 (0=正常,1=异常)', fontproperties=font)
    plt.title(f'异常检测结果对比（前{length}步）', fontproperties=font)
    plt.legend(prop=font)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

def plot_confusion_matrix(true_labels, pred_labels):
    cm = confusion_matrix(true_labels, pred_labels)
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['正常','异常'], yticklabels=['正常','异常'])
    plt.xlabel('预测标签', fontproperties=font)
    plt.ylabel('真实标签', fontproperties=font)
    plt.title('混淆矩阵', fontproperties=font)
    plt.show()

def plot_roc_curve(true_labels, pred_probs):
    fpr, tpr, _ = roc_curve(true_labels, pred_probs)
    roc_auc = auc(fpr, tpr)
    plt.figure(figsize=(6,5))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC曲线 (AUC = {roc_auc:.4f})')
    plt.plot([0,1], [0,1], color='navy', lw=2, linestyle='--')
    plt.xlabel('假阳性率 (FPR)', fontproperties=font)
    plt.ylabel('真阳性率 (TPR)', fontproperties=font)
    plt.title('ROC曲线', fontproperties=font)
    plt.legend(loc='lower right', prop=font)
    plt.grid(True)
    plt.show()

def plot_precision_recall_curve(true_labels, pred_probs):
    precision, recall, _ = precision_recall_curve(true_labels, pred_probs)
    pr_auc = auc(recall, precision)
    plt.figure(figsize=(6,5))
    plt.plot(recall, precision, color='purple', lw=2, label=f'PR曲线 (AUC = {pr_auc:.4f})')
    plt.xlabel('召回率 (Recall)', fontproperties=font)
    plt.ylabel('精确率 (Precision)', fontproperties=font)
    plt.title('精确率-召回率曲线', fontproperties=font)
    plt.legend(loc='lower left', prop=font)
    plt.grid(True)
    plt.show()

# ----------------------------
test_files = [f for f in sampled_files if any(s in f for s in test_sns)]
all_true, all_preds, all_probs = test_agent(agent, data_dict, test_files, window_size=WINDOW_SIZE, target_length=TARGET_LENGTH)
# Out:
# Using device: cpu
# Using all 2612 files for training/testing.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Warning: file 00579_018_SN06_24bars_offmod.csv not found in data directory.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Warning: file 01269_001_SN13_24bars_ssf.csv not found in data directory.
# Warning: file 01270_002_SN13_21bars_ssf.csv not found in data directory.
# Warning: file 01271_003_SN13_18bars_ssf.csv not found in data directory.
# Warning: file 01272_004_SN13_15bars_ssf.csv not found in data directory.
# Warning: file 01273_005_SN13_12bars_ssf.csv not found in data directory.
# Warning: file 01274_006_SN13_9bars_ssf.csv not found in data directory.
# Warning: file 01275_007_SN13_24bars_health_check.csv not found in data directory.
# Warning: file 01276_008_SN13_21bars_health_check.csv not found in data directory.
# Warning: file 01277_009_SN13_18bars_health_check.csv not found in data directory.
# Warning: file 01278_010_SN13_15bars_health_check.csv not found in data directory.
# Warning: file 01279_011_SN13_12bars_health_check.csv not found in data directory.
# Warning: file 01280_012_SN13_9bars_health_check.csv not found in data directory.
# Warning: file 01281_013_SN13_24bars_ramp1.csv not found in data directory.
# Warning: file 01282_014_SN13_24bars_ramp2.csv not found in data directory.
# Warning: file 01283_015_SN13_24bars_ramp3.csv not found in data directory.
# Warning: file 01284_016_SN13_24bars_ramp4.csv not found in data directory.
# Warning: file 01285_017_SN13_24bars_onmod.csv not found in data directory.
# Warning: file 01286_018_SN13_24bars_offmod.csv not found in data directory.
# Warning: file 01287_019_SN13_24bars_random_short.csv not found in data directory.
# Warning: file 01288_020_SN13_24bars_random_long.csv not found in data directory.
# Warning: file 01289_021_SN13_24bars_random_mixed.csv not found in data directory.
# Warning: file 01290_022_SN13_21bars_ramp1.csv not found in data directory.
# Warning: file 01291_023_SN13_21bars_ramp2.csv not found in data directory.
# Warning: file 01292_024_SN13_21bars_ramp3.csv not found in data directory.
# Warning: file 01293_025_SN13_21bars_ramp4.csv not found in data directory.
# Warning: file 01294_026_SN13_21bars_onmod.csv not found in data directory.
# Warning: file 01295_027_SN13_21bars_offmod.csv not found in data directory.
# Warning: file 01296_028_SN13_21bars_random_short.csv not found in data directory.
# Warning: file 01297_029_SN13_21bars_random_long.csv not found in data directory.
# Warning: file 01298_030_SN13_21bars_random_mixed.csv not found in data directory.
# Warning: file 01299_031_SN13_18bars_ramp1.csv not found in data directory.
# Warning: file 01300_032_SN13_18bars_ramp2.csv not found in data directory.
# Warning: file 01301_033_SN13_18bars_ramp3.csv not found in data directory.
# Warning: file 01302_034_SN13_18bars_ramp4.csv not found in data directory.
# Warning: file 01303_035_SN13_18bars_onmod.csv not found in data directory.
# Warning: file 01304_036_SN13_18bars_offmod.csv not found in data directory.
# Warning: file 01305_037_SN13_18bars_random_short.csv not found in data directory.
# Warning: file 01306_038_SN13_18bars_random_long.csv not found in data directory.
# Warning: file 01307_039_SN13_18bars_random_mixed.csv not found in data directory.
# Warning: file 01308_040_SN13_24bars_ssf.csv not found in data directory.
# Warning: file 01309_041_SN13_21bars_ssf.csv not found in data directory.
# Warning: file 01310_042_SN13_18bars_ssf.csv not found in data directory.
# Warning: file 01311_043_SN13_15bars_ssf.csv not found in data directory.
# Warning: file 01312_044_SN13_12bars_ssf.csv not found in data directory.
# Warning: file 01313_045_SN13_9bars_ssf.csv not found in data directory.
# Warning: file 01314_046_SN13_24bars_health_check.csv not found in data directory.
# Warning: file 01315_047_SN13_21bars_health_check.csv not found in data directory.
# Warning: file 01316_048_SN13_18bars_health_check.csv not found in data directory.
# Warning: file 01317_049_SN13_15bars_health_check.csv not found in data directory.
# Warning: file 01318_050_SN13_12bars_health_check.csv not found in data directory.
# Warning: file 01319_051_SN13_9bars_health_check.csv not found in data directory.
# Warning: file 01320_052_SN13_15bars_ramp1.csv not found in data directory.
# Warning: file 01321_053_SN13_15bars_ramp2.csv not found in data directory.
# Warning: file 01322_054_SN13_15bars_ramp3.csv not found in data directory.
# Warning: file 01323_055_SN13_15bars_ramp4.csv not found in data directory.
# Warning: file 01324_056_SN13_15bars_onmod.csv not found in data directory.
# Warning: file 01325_057_SN13_15bars_offmod.csv not found in data directory.
# Warning: file 01326_058_SN13_15bars_random_short.csv not found in data directory.
# Warning: file 01327_059_SN13_15bars_random_long.csv not found in data directory.
# Warning: file 01328_060_SN13_15bars_random_mixed.csv not found in data directory.
# Warning: file 01329_061_SN13_12bars_ramp1.csv not found in data directory.
# Warning: file 01330_062_SN13_12bars_ramp2.csv not found in data directory.
# Warning: file 01331_063_SN13_12bars_ramp3.csv not found in data directory.
# Warning: file 01332_064_SN13_12bars_ramp4.csv not found in data directory.
# Warning: file 01333_065_SN13_12bars_onmod.csv not found in data directory.
# Warning: file 01334_066_SN13_12bars_offmod.csv not found in data directory.
# Warning: file 01335_067_SN13_12bars_random_short.csv not found in data directory.
# Warning: file 01336_068_SN13_12bars_random_long.csv not found in data directory.
# Warning: file 01337_069_SN13_12bars_random_mixed.csv not found in data directory.
# Warning: file 01338_070_SN13_9bars_ramp1.csv not found in data directory.
# Warning: file 01339_071_SN13_9bars_ramp2.csv not found in data directory.
# Warning: file 01340_072_SN13_9bars_ramp3.csv not found in data directory.
# Warning: file 01341_073_SN13_9bars_ramp4.csv not found in data directory.
# Warning: file 01342_074_SN13_9bars_onmod.csv not found in data directory.
# Warning: file 01343_075_SN13_9bars_offmod.csv not found in data directory.
# Warning: file 01344_076_SN13_9bars_random_short.csv not found in data directory.
# Warning: file 01345_077_SN13_9bars_random_long.csv not found in data directory.
# Warning: file 01346_078_SN13_9bars_random_mixed.csv not found in data directory.
# Warning: file 01347_079_SN13_24bars_ssf.csv not found in data directory.
# Warning: file 01348_080_SN13_21bars_ssf.csv not found in data directory.
# Warning: file 01349_081_SN13_18bars_ssf.csv not found in data directory.
# Warning: file 01350_082_SN13_15bars_ssf.csv not found in data directory.
# Warning: file 01351_083_SN13_12bars_ssf.csv not found in data directory.
# Warning: file 01352_084_SN13_9bars_ssf.csv not found in data directory.
# Warning: file 01353_085_SN13_24bars_health_check.csv not found in data directory.
# Warning: file 01354_086_SN13_21bars_health_check.csv not found in data directory.
# Warning: file 01355_087_SN13_18bars_health_check.csv not found in data directory.
# Warning: file 01356_088_SN13_15bars_health_check.csv not found in data directory.
# Warning: file 01357_089_SN13_12bars_health_check.csv not found in data directory.
# Warning: file 01358_090_SN13_9bars_health_check.csv not found in data directory.
# Warning: file 01359_091_SN13_7bars_ssf.csv not found in data directory.
# Warning: file 01360_092_SN13_5bars_ssf.csv not found in data directory.
# Warning: file 01361_093_SN13_7bars_health_check.csv not found in data directory.
# Warning: file 01362_094_SN13_5bars_health_check.csv not found in data directory.
# Warning: file 01363_095_SN13_7bars_ramp1.csv not found in data directory.
# Warning: file 01364_096_SN13_7bars_ramp2.csv not found in data directory.
# Warning: file 01365_097_SN13_7bars_ramp3.csv not found in data directory.
# Warning: file 01366_098_SN13_7bars_ramp4.csv not found in data directory.
# Warning: file 01367_099_SN13_7bars_onmod.csv not found in data directory.
# Warning: file 01368_100_SN13_7bars_offmod.csv not found in data directory.
# Warning: file 01369_101_SN13_7bars_random_short.csv not found in data directory.
# Warning: file 01370_102_SN13_7bars_random_long.csv not found in data directory.
# Warning: file 01371_103_SN13_7bars_random_mixed.csv not found in data directory.
# Warning: file 01372_104_SN13_5bars_ramp1.csv not found in data directory.
# Warning: file 01373_105_SN13_5bars_ramp2.csv not found in data directory.
# Warning: file 01374_106_SN13_5bars_ramp3.csv not found in data directory.
# Warning: file 01375_107_SN13_5bars_ramp4.csv not found in data directory.
# Warning: file 01376_108_SN13_5bars_onmod.csv not found in data directory.
# Warning: file 01377_109_SN13_5bars_offmod.csv not found in data directory.
# Warning: file 01378_110_SN13_5bars_random_short.csv not found in data directory.
# Warning: file 01379_111_SN13_5bars_random_long.csv not found in data directory.
# Warning: file 01380_112_SN13_5bars_random_mixed.csv not found in data directory.
# Warning: file 01381_001_SN14_24bars_ssf.csv not found in data directory.
# Warning: file 01382_002_SN14_21bars_ssf.csv not found in data directory.
# Warning: file 01383_003_SN14_18bars_ssf.csv not found in data directory.
# Warning: file 01384_004_SN14_15bars_ssf.csv not found in data directory.
# Warning: file 01385_005_SN14_12bars_ssf.csv not found in data directory.
# Warning: file 01386_006_SN14_9bars_ssf.csv not found in data directory.
# Warning: file 01387_007_SN14_24bars_health_check.csv not found in data directory.
# Warning: file 01388_008_SN14_21bars_health_check.csv not found in data directory.
# Warning: file 01389_009_SN14_18bars_health_check.csv not found in data directory.
# Warning: file 01390_010_SN14_15bars_health_check.csv not found in data directory.
# Warning: file 01391_011_SN14_12bars_health_check.csv not found in data directory.
# Warning: file 01392_012_SN14_9bars_health_check.csv not found in data directory.
# Warning: file 01393_013_SN14_24bars_ramp1.csv not found in data directory.
# Warning: file 01394_014_SN14_24bars_ramp2.csv not found in data directory.
# Warning: file 01395_015_SN14_24bars_ramp3.csv not found in data directory.
# Warning: file 01396_016_SN14_24bars_ramp4.csv not found in data directory.
# Warning: file 01397_017_SN14_24bars_onmod.csv not found in data directory.
# Warning: file 01398_018_SN14_24bars_offmod.csv not found in data directory.
# Warning: file 01399_019_SN14_24bars_random_short.csv not found in data directory.
# Warning: file 01400_020_SN14_24bars_random_long.csv not found in data directory.
# Warning: file 01401_021_SN14_24bars_random_mixed.csv not found in data directory.
# Warning: file 01402_022_SN14_21bars_ramp1.csv not found in data directory.
# Warning: file 01403_023_SN14_21bars_ramp2.csv not found in data directory.
# Warning: file 01404_024_SN14_21bars_ramp3.csv not found in data directory.
# Warning: file 01405_025_SN14_21bars_ramp4.csv not found in data directory.
# Warning: file 01406_026_SN14_21bars_onmod.csv not found in data directory.
# Warning: file 01407_027_SN14_21bars_offmod.csv not found in data directory.
# Warning: file 01408_028_SN14_21bars_random_short.csv not found in data directory.
# Warning: file 01409_029_SN14_21bars_random_long.csv not found in data directory.
# Warning: file 01410_030_SN14_21bars_random_mixed.csv not found in data directory.
# Warning: file 01411_031_SN14_18bars_ramp1.csv not found in data directory.
# Warning: file 01412_032_SN14_18bars_ramp2.csv not found in data directory.
# Warning: file 01413_033_SN14_18bars_ramp3.csv not found in data directory.
# Warning: file 01414_034_SN14_18bars_ramp4.csv not found in data directory.
# Warning: file 01415_035_SN14_18bars_onmod.csv not found in data directory.
# Warning: file 01416_036_SN14_18bars_offmod.csv not found in data directory.
# Warning: file 01417_037_SN14_18bars_random_short.csv not found in data directory.
# Warning: file 01418_038_SN14_18bars_random_long.csv not found in data directory.
# Warning: file 01419_039_SN14_18bars_random_mixed.csv not found in data directory.
# Warning: file 01420_040_SN14_24bars_ssf.csv not found in data directory.
# Warning: file 01421_041_SN14_21bars_ssf.csv not found in data directory.
# Warning: file 01422_042_SN14_18bars_ssf.csv not found in data directory.
# Warning: file 01423_043_SN14_15bars_ssf.csv not found in data directory.
# Warning: file 01424_044_SN14_12bars_ssf.csv not found in data directory.
# Warning: file 01425_045_SN14_9bars_ssf.csv not found in data directory.
# Warning: file 01426_046_SN14_24bars_health_check.csv not found in data directory.
# Warning: file 01427_047_SN14_21bars_health_check.csv not found in data directory.
# Warning: file 01428_048_SN14_18bars_health_check.csv not found in data directory.
# Warning: file 01429_049_SN14_15bars_health_check.csv not found in data directory.
# Warning: file 01430_050_SN14_12bars_health_check.csv not found in data directory.
# Warning: file 01431_051_SN14_9bars_health_check.csv not found in data directory.
# Warning: file 01432_052_SN14_15bars_ramp1.csv not found in data directory.
# Warning: file 01433_053_SN14_15bars_ramp2.csv not found in data directory.
# Warning: file 01434_054_SN14_15bars_ramp3.csv not found in data directory.
# Warning: file 01435_055_SN14_15bars_ramp4.csv not found in data directory.
# Warning: file 01436_056_SN14_15bars_onmod.csv not found in data directory.
# Warning: file 01437_057_SN14_15bars_offmod.csv not found in data directory.
# Warning: file 01438_058_SN14_15bars_random_short.csv not found in data directory.
# Warning: file 01439_059_SN14_15bars_random_long.csv not found in data directory.
# Warning: file 01440_060_SN14_15bars_random_mixed.csv not found in data directory.
# Warning: file 01441_061_SN14_12bars_ramp1.csv not found in data directory.
# Warning: file 01442_062_SN14_12bars_ramp2.csv not found in data directory.
# Warning: file 01443_063_SN14_12bars_ramp3.csv not found in data directory.
# Warning: file 01444_064_SN14_12bars_ramp4.csv not found in data directory.
# Warning: file 01445_065_SN14_12bars_onmod.csv not found in data directory.
# Warning: file 01446_066_SN14_12bars_offmod.csv not found in data directory.
# Warning: file 01447_067_SN14_12bars_random_short.csv not found in data directory.
# Warning: file 01448_068_SN14_12bars_random_long.csv not found in data directory.
# Warning: file 01449_069_SN14_12bars_random_mixed.csv not found in data directory.
# Warning: file 01450_070_SN14_9bars_ramp1.csv not found in data directory.
# Warning: file 01451_071_SN14_9bars_ramp2.csv not found in data directory.
# Warning: file 01452_072_SN14_9bars_ramp3.csv not found in data directory.
# Warning: file 01453_073_SN14_9bars_ramp4.csv not found in data directory.
# Warning: file 01454_074_SN14_9bars_onmod.csv not found in data directory.
# Warning: file 01455_075_SN14_9bars_offmod.csv not found in data directory.
# Warning: file 01456_076_SN14_9bars_random_short.csv not found in data directory.
# Warning: file 01457_077_SN14_9bars_random_long.csv not found in data directory.
# Warning: file 01458_078_SN14_9bars_random_mixed.csv not found in data directory.
# Warning: file 01459_079_SN14_24bars_ssf.csv not found in data directory.
# Warning: file 01460_080_SN14_21bars_ssf.csv not found in data directory.
# Warning: file 01461_081_SN14_18bars_ssf.csv not found in data directory.
# Warning: file 01462_082_SN14_15bars_ssf.csv not found in data directory.
# Warning: file 01463_083_SN14_12bars_ssf.csv not found in data directory.
# Warning: file 01464_084_SN14_9bars_ssf.csv not found in data directory.
# Warning: file 01465_085_SN14_24bars_health_check.csv not found in data directory.
# Warning: file 01466_086_SN14_21bars_health_check.csv not found in data directory.
# Warning: file 01467_087_SN14_18bars_health_check.csv not found in data directory.
# Warning: file 01468_088_SN14_15bars_health_check.csv not found in data directory.
# Warning: file 01469_089_SN14_12bars_health_check.csv not found in data directory.
# Warning: file 01470_090_SN14_9bars_health_check.csv not found in data directory.
# Warning: file 01471_091_SN14_7bars_ssf.csv not found in data directory.
# Warning: file 01472_092_SN14_5bars_ssf.csv not found in data directory.
# Warning: file 01473_093_SN14_7bars_health_check.csv not found in data directory.
# Warning: file 01474_094_SN14_5bars_health_check.csv not found in data directory.
# Warning: file 01475_095_SN14_7bars_ramp1.csv not found in data directory.
# Warning: file 01476_096_SN14_7bars_ramp2.csv not found in data directory.
# Warning: file 01477_097_SN14_7bars_ramp3.csv not found in data directory.
# Warning: file 01478_098_SN14_7bars_ramp4.csv not found in data directory.
# Warning: file 01479_099_SN14_7bars_onmod.csv not found in data directory.
# Warning: file 01480_100_SN14_7bars_offmod.csv not found in data directory.
# Warning: file 01481_101_SN14_7bars_random_short.csv not found in data directory.
# Warning: file 01482_102_SN14_7bars_random_long.csv not found in data directory.
# Warning: file 01483_103_SN14_7bars_random_mixed.csv not found in data directory.
# Warning: file 01484_104_SN14_5bars_ramp1.csv not found in data directory.
# Warning: file 01485_105_SN14_5bars_ramp2.csv not found in data directory.
# Warning: file 01486_106_SN14_5bars_ramp3.csv not found in data directory.
# Warning: file 01487_107_SN14_5bars_ramp4.csv not found in data directory.
# Warning: file 01488_108_SN14_5bars_onmod.csv not found in data directory.
# Warning: file 01489_109_SN14_5bars_offmod.csv not found in data directory.
# Warning: file 01490_110_SN14_5bars_random_short.csv not found in data directory.
# Warning: file 01491_111_SN14_5bars_random_long.csv not found in data directory.
# Warning: file 01492_112_SN14_5bars_random_mixed.csv not found in data directory.
# Warning: file 01493_001_SN15_24bars_ssf.csv not found in data directory.
# Warning: file 01494_002_SN15_21bars_ssf.csv not found in data directory.
# Warning: file 01495_003_SN15_18bars_ssf.csv not found in data directory.
# Warning: file 01496_004_SN15_15bars_ssf.csv not found in data directory.
# Warning: file 01497_005_SN15_12bars_ssf.csv not found in data directory.
# Warning: file 01498_006_SN15_9bars_ssf.csv not found in data directory.
# Warning: file 01499_007_SN15_24bars_health_check.csv not found in data directory.
# Warning: file 01500_008_SN15_21bars_health_check.csv not found in data directory.
# Warning: file 01501_009_SN15_18bars_health_check.csv not found in data directory.
# Warning: file 01502_010_SN15_15bars_health_check.csv not found in data directory.
# Warning: file 01503_011_SN15_12bars_health_check.csv not found in data directory.
# Warning: file 01504_012_SN15_9bars_health_check.csv not found in data directory.
# Warning: file 01505_013_SN15_24bars_ramp1.csv not found in data directory.
# Warning: file 01506_014_SN15_24bars_ramp2.csv not found in data directory.
# Warning: file 01507_015_SN15_24bars_ramp3.csv not found in data directory.
# Warning: file 01508_016_SN15_24bars_ramp4.csv not found in data directory.
# Warning: file 01509_017_SN15_24bars_onmod.csv not found in data directory.
# Warning: file 01510_018_SN15_24bars_offmod.csv not found in data directory.
# Warning: file 01511_019_SN15_24bars_random_short.csv not found in data directory.
# Warning: file 01512_020_SN15_24bars_random_long.csv not found in data directory.
# Warning: file 01513_021_SN15_24bars_random_mixed.csv not found in data directory.
# Warning: file 01514_022_SN15_21bars_ramp1.csv not found in data directory.
# Warning: file 01515_023_SN15_21bars_ramp2.csv not found in data directory.
# Warning: file 01516_024_SN15_21bars_ramp3.csv not found in data directory.
# Warning: file 01517_025_SN15_21bars_ramp4.csv not found in data directory.
# Warning: file 01518_026_SN15_21bars_onmod.csv not found in data directory.
# Warning: file 01519_027_SN15_21bars_offmod.csv not found in data directory.
# Warning: file 01520_028_SN15_21bars_random_short.csv not found in data directory.
# Warning: file 01521_029_SN15_21bars_random_long.csv not found in data directory.
# Warning: file 01522_030_SN15_21bars_random_mixed.csv not found in data directory.
# Warning: file 01523_031_SN15_18bars_ramp1.csv not found in data directory.
# Warning: file 01524_032_SN15_18bars_ramp2.csv not found in data directory.
# Warning: file 01525_033_SN15_18bars_ramp3.csv not found in data directory.
# Warning: file 01526_034_SN15_18bars_ramp4.csv not found in data directory.
# Warning: file 01527_035_SN15_18bars_onmod.csv not found in data directory.
# Warning: file 01528_036_SN15_18bars_offmod.csv not found in data directory.
# Warning: file 01529_037_SN15_18bars_random_short.csv not found in data directory.
# Warning: file 01530_038_SN15_18bars_random_long.csv not found in data directory.
# Warning: file 01531_039_SN15_18bars_random_mixed.csv not found in data directory.
# Warning: file 01532_040_SN15_24bars_ssf.csv not found in data directory.
# Warning: file 01533_041_SN15_21bars_ssf.csv not found in data directory.
# Warning: file 01534_042_SN15_18bars_ssf.csv not found in data directory.
# Warning: file 01535_043_SN15_15bars_ssf.csv not found in data directory.
# Warning: file 01536_044_SN15_12bars_ssf.csv not found in data directory.
# Warning: file 01537_045_SN15_9bars_ssf.csv not found in data directory.
# Warning: file 01538_046_SN15_24bars_health_check.csv not found in data directory.
# Warning: file 01539_047_SN15_21bars_health_check.csv not found in data directory.
# Warning: file 01540_048_SN15_18bars_health_check.csv not found in data directory.
# Warning: file 01541_049_SN15_15bars_health_check.csv not found in data directory.
# Warning: file 01542_050_SN15_12bars_health_check.csv not found in data directory.
# Warning: file 01543_051_SN15_9bars_health_check.csv not found in data directory.
# Warning: file 01544_052_SN15_15bars_ramp1.csv not found in data directory.
# Warning: file 01545_053_SN15_15bars_ramp2.csv not found in data directory.
# Warning: file 01546_054_SN15_15bars_ramp3.csv not found in data directory.
# Warning: file 01547_055_SN15_15bars_ramp4.csv not found in data directory.
# Warning: file 01548_056_SN15_15bars_onmod.csv not found in data directory.
# Warning: file 01549_057_SN15_15bars_offmod.csv not found in data directory.
# Warning: file 01550_058_SN15_15bars_random_short.csv not found in data directory.
# Warning: file 01551_059_SN15_15bars_random_long.csv not found in data directory.
# Warning: file 01552_060_SN15_15bars_random_mixed.csv not found in data directory.
# Warning: file 01553_061_SN15_12bars_ramp1.csv not found in data directory.
# Warning: file 01554_062_SN15_12bars_ramp2.csv not found in data directory.
# Warning: file 01555_063_SN15_12bars_ramp3.csv not found in data directory.
# Warning: file 01556_064_SN15_12bars_ramp4.csv not found in data directory.
# Warning: file 01557_065_SN15_12bars_onmod.csv not found in data directory.
# Warning: file 01558_066_SN15_12bars_offmod.csv not found in data directory.
# Warning: file 01559_067_SN15_12bars_random_short.csv not found in data directory.
# Warning: file 01560_068_SN15_12bars_random_long.csv not found in data directory.
# Warning: file 01561_069_SN15_12bars_random_mixed.csv not found in data directory.
# Warning: file 01562_070_SN15_9bars_ramp1.csv not found in data directory.
# Warning: file 01563_071_SN15_9bars_ramp2.csv not found in data directory.
# Warning: file 01564_072_SN15_9bars_ramp3.csv not found in data directory.
# Warning: file 01565_073_SN15_9bars_ramp4.csv not found in data directory.
# Warning: file 01566_074_SN15_9bars_onmod.csv not found in data directory.
# Warning: file 01567_075_SN15_9bars_offmod.csv not found in data directory.
# Warning: file 01568_076_SN15_9bars_random_short.csv not found in data directory.
# Warning: file 01569_077_SN15_9bars_random_long.csv not found in data directory.
# Warning: file 01570_078_SN15_9bars_random_mixed.csv not found in data directory.
# Warning: file 01571_079_SN15_24bars_ssf.csv not found in data directory.
# Warning: file 01572_080_SN15_21bars_ssf.csv not found in data directory.
# Warning: file 01573_081_SN15_18bars_ssf.csv not found in data directory.
# Warning: file 01574_082_SN15_15bars_ssf.csv not found in data directory.
# Warning: file 01575_083_SN15_12bars_ssf.csv not found in data directory.
# Warning: file 01576_084_SN15_9bars_ssf.csv not found in data directory.
# Warning: file 01577_085_SN15_24bars_health_check.csv not found in data directory.
# Warning: file 01578_086_SN15_21bars_health_check.csv not found in data directory.
# Warning: file 01579_087_SN15_18bars_health_check.csv not found in data directory.
# Warning: file 01580_088_SN15_15bars_health_check.csv not found in data directory.
# Warning: file 01581_089_SN15_12bars_health_check.csv not found in data directory.
# Warning: file 01582_090_SN15_9bars_health_check.csv not found in data directory.
# Warning: file 01583_091_SN15_7bars_ssf.csv not found in data directory.
# Warning: file 01584_092_SN15_5bars_ssf.csv not found in data directory.
# Warning: file 01585_093_SN15_7bars_health_check.csv not found in data directory.
# Warning: file 01586_094_SN15_5bars_health_check.csv not found in data directory.
# Warning: file 01587_095_SN15_7bars_ramp1.csv not found in data directory.
# Warning: file 01588_096_SN15_7bars_ramp2.csv not found in data directory.
# Warning: file 01589_097_SN15_7bars_ramp3.csv not found in data directory.
# Warning: file 01590_098_SN15_7bars_ramp4.csv not found in data directory.
# Warning: file 01591_099_SN15_7bars_onmod.csv not found in data directory.
# Warning: file 01592_100_SN15_7bars_offmod.csv not found in data directory.
# Warning: file 01593_101_SN15_7bars_random_short.csv not found in data directory.
# Warning: file 01594_102_SN15_7bars_random_long.csv not found in data directory.
# Warning: file 01595_103_SN15_7bars_random_mixed.csv not found in data directory.
# Warning: file 01596_104_SN15_5bars_ramp1.csv not found in data directory.
# Warning: file 01597_105_SN15_5bars_ramp2.csv not found in data directory.
# Warning: file 01598_106_SN15_5bars_ramp3.csv not found in data directory.
# Warning: file 01599_107_SN15_5bars_ramp4.csv not found in data directory.
# Warning: file 01600_108_SN15_5bars_onmod.csv not found in data directory.
# Warning: file 01601_109_SN15_5bars_offmod.csv not found in data directory.
# Warning: file 01602_110_SN15_5bars_random_short.csv not found in data directory.
# Warning: file 01603_111_SN15_5bars_random_long.csv not found in data directory.
# Warning: file 01604_112_SN15_5bars_random_mixed.csv not found in data directory.
# Warning: file 01605_001_SN16_24bars_ssf.csv not found in data directory.
# Warning: file 01606_002_SN16_21bars_ssf.csv not found in data directory.
# Warning: file 01607_003_SN16_18bars_ssf.csv not found in data directory.
# Warning: file 01608_004_SN16_15bars_ssf.csv not found in data directory.
# Warning: file 01609_005_SN16_12bars_ssf.csv not found in data directory.
# Warning: file 01610_006_SN16_9bars_ssf.csv not found in data directory.
# Warning: file 01611_007_SN16_24bars_health_check.csv not found in data directory.
# Warning: file 01612_008_SN16_21bars_health_check.csv not found in data directory.
# Warning: file 01613_009_SN16_18bars_health_check.csv not found in data directory.
# Warning: file 01614_010_SN16_15bars_health_check.csv not found in data directory.
# Warning: file 01615_011_SN16_12bars_health_check.csv not found in data directory.
# Warning: file 01616_012_SN16_9bars_health_check.csv not found in data directory.
# Warning: file 01617_013_SN16_24bars_ramp1.csv not found in data directory.
# Warning: file 01618_014_SN16_24bars_ramp2.csv not found in data directory.
# Warning: file 01619_015_SN16_24bars_ramp3.csv not found in data directory.
# Warning: file 01620_016_SN16_24bars_ramp4.csv not found in data directory.
# Warning: file 01621_017_SN16_24bars_onmod.csv not found in data directory.
# Warning: file 01622_018_SN16_24bars_offmod.csv not found in data directory.
# Warning: file 01623_019_SN16_24bars_random_short.csv not found in data directory.
# Warning: file 01624_020_SN16_24bars_random_long.csv not found in data directory.
# Warning: file 01625_021_SN16_24bars_random_mixed.csv not found in data directory.
# Warning: file 01626_022_SN16_21bars_ramp1.csv not found in data directory.
# Warning: file 01627_023_SN16_21bars_ramp2.csv not found in data directory.
# Warning: file 01628_024_SN16_21bars_ramp3.csv not found in data directory.
# Warning: file 01629_025_SN16_21bars_ramp4.csv not found in data directory.
# Warning: file 01630_026_SN16_21bars_onmod.csv not found in data directory.
# Warning: file 01631_027_SN16_21bars_offmod.csv not found in data directory.
# Warning: file 01632_028_SN16_21bars_random_short.csv not found in data directory.
# Warning: file 01633_029_SN16_21bars_random_long.csv not found in data directory.
# Warning: file 01634_030_SN16_21bars_random_mixed.csv not found in data directory.
# Warning: file 01635_031_SN16_18bars_ramp1.csv not found in data directory.
# Warning: file 01636_032_SN16_18bars_ramp2.csv not found in data directory.
# Warning: file 01637_033_SN16_18bars_ramp3.csv not found in data directory.
# Warning: file 01638_034_SN16_18bars_ramp4.csv not found in data directory.
# Warning: file 01639_035_SN16_18bars_onmod.csv not found in data directory.
# Warning: file 01640_036_SN16_18bars_offmod.csv not found in data directory.
# Warning: file 01641_037_SN16_18bars_random_short.csv not found in data directory.
# Warning: file 01642_038_SN16_18bars_random_long.csv not found in data directory.
# Warning: file 01643_039_SN16_18bars_random_mixed.csv not found in data directory.
# Warning: file 01644_040_SN16_24bars_ssf.csv not found in data directory.
# Warning: file 01645_041_SN16_21bars_ssf.csv not found in data directory.
# Warning: file 01646_042_SN16_18bars_ssf.csv not found in data directory.
# Warning: file 01647_043_SN16_15bars_ssf.csv not found in data directory.
# Warning: file 01648_044_SN16_12bars_ssf.csv not found in data directory.
# Warning: file 01649_045_SN16_9bars_ssf.csv not found in data directory.
# Warning: file 01650_046_SN16_24bars_health_check.csv not found in data directory.
# Warning: file 01651_047_SN16_21bars_health_check.csv not found in data directory.
# Warning: file 01652_048_SN16_18bars_health_check.csv not found in data directory.
# Warning: file 01653_049_SN16_15bars_health_check.csv not found in data directory.
# Warning: file 01654_050_SN16_12bars_health_check.csv not found in data directory.
# Warning: file 01655_051_SN16_9bars_health_check.csv not found in data directory.
# Warning: file 01656_052_SN16_15bars_ramp1.csv not found in data directory.
# Warning: file 01657_053_SN16_15bars_ramp2.csv not found in data directory.
# Warning: file 01658_054_SN16_15bars_ramp3.csv not found in data directory.
# Warning: file 01659_055_SN16_15bars_ramp4.csv not found in data directory.
# Warning: file 01660_056_SN16_15bars_onmod.csv not found in data directory.
# Warning: file 01661_057_SN16_15bars_offmod.csv not found in data directory.
# Warning: file 01662_058_SN16_15bars_random_short.csv not found in data directory.
# Warning: file 01663_059_SN16_15bars_random_long.csv not found in data directory.
# Warning: file 01664_060_SN16_15bars_random_mixed.csv not found in data directory.
# Warning: file 01665_061_SN16_12bars_ramp1.csv not found in data directory.
# Warning: file 01666_062_SN16_12bars_ramp2.csv not found in data directory.
# Warning: file 01667_063_SN16_12bars_ramp3.csv not found in data directory.
# Warning: file 01668_064_SN16_12bars_ramp4.csv not found in data directory.
# Warning: file 01669_065_SN16_12bars_onmod.csv not found in data directory.
# Warning: file 01670_066_SN16_12bars_offmod.csv not found in data directory.
# Warning: file 01671_067_SN16_12bars_random_short.csv not found in data directory.
# Warning: file 01672_068_SN16_12bars_random_long.csv not found in data directory.
# Warning: file 01673_069_SN16_12bars_random_mixed.csv not found in data directory.
# Warning: file 01674_070_SN16_9bars_ramp1.csv not found in data directory.
# Warning: file 01675_071_SN16_9bars_ramp2.csv not found in data directory.
# Warning: file 01676_072_SN16_9bars_ramp3.csv not found in data directory.
# Warning: file 01677_073_SN16_9bars_ramp4.csv not found in data directory.
# Warning: file 01678_074_SN16_9bars_onmod.csv not found in data directory.
# Warning: file 01679_075_SN16_9bars_offmod.csv not found in data directory.
# Warning: file 01680_076_SN16_9bars_random_short.csv not found in data directory.
# Warning: file 01681_077_SN16_9bars_random_long.csv not found in data directory.
# Warning: file 01682_078_SN16_9bars_random_mixed.csv not found in data directory.
# Warning: file 01683_079_SN16_24bars_ssf.csv not found in data directory.
# Warning: file 01684_080_SN16_21bars_ssf.csv not found in data directory.
# Warning: file 01685_081_SN16_18bars_ssf.csv not found in data directory.
# Warning: file 01686_082_SN16_15bars_ssf.csv not found in data directory.
# Warning: file 01687_083_SN16_12bars_ssf.csv not found in data directory.
# Warning: file 01688_084_SN16_9bars_ssf.csv not found in data directory.
# Warning: file 01689_085_SN16_24bars_health_check.csv not found in data directory.
# Warning: file 01690_086_SN16_21bars_health_check.csv not found in data directory.
# Warning: file 01691_087_SN16_18bars_health_check.csv not found in data directory.
# Warning: file 01692_088_SN16_15bars_health_check.csv not found in data directory.
# Warning: file 01693_089_SN16_12bars_health_check.csv not found in data directory.
# Warning: file 01694_090_SN16_9bars_health_check.csv not found in data directory.
# Warning: file 01695_091_SN16_7bars_ssf.csv not found in data directory.
# Warning: file 01696_092_SN16_5bars_ssf.csv not found in data directory.
# Warning: file 01697_093_SN16_7bars_health_check.csv not found in data directory.
# Warning: file 01698_094_SN16_5bars_health_check.csv not found in data directory.
# Warning: file 01699_095_SN16_7bars_ramp1.csv not found in data directory.
# Warning: file 01700_096_SN16_7bars_ramp2.csv not found in data directory.
# Warning: file 01701_097_SN16_7bars_ramp3.csv not found in data directory.
# Warning: file 01702_098_SN16_7bars_ramp4.csv not found in data directory.
# Warning: file 01703_099_SN16_7bars_onmod.csv not found in data directory.
# Warning: file 01704_100_SN16_7bars_offmod.csv not found in data directory.
# Warning: file 01705_101_SN16_7bars_random_short.csv not found in data directory.
# Warning: file 01706_102_SN16_7bars_random_long.csv not found in data directory.
# Warning: file 01707_103_SN16_7bars_random_mixed.csv not found in data directory.
# Warning: file 01708_104_SN16_5bars_ramp1.csv not found in data directory.
# Warning: file 01709_105_SN16_5bars_ramp2.csv not found in data directory.
# Warning: file 01710_106_SN16_5bars_ramp3.csv not found in data directory.
# Warning: file 01711_107_SN16_5bars_ramp4.csv not found in data directory.
# Warning: file 01712_108_SN16_5bars_onmod.csv not found in data directory.
# Warning: file 01713_109_SN16_5bars_offmod.csv not found in data directory.
# Warning: file 01714_110_SN16_5bars_random_short.csv not found in data directory.
# Warning: file 01715_111_SN16_5bars_random_long.csv not found in data directory.
# Warning: file 01716_112_SN16_5bars_random_mixed.csv not found in data directory.
# Warning: file 01717_001_SN17_24bars_ssf.csv not found in data directory.
# Warning: file 01718_002_SN17_21bars_ssf.csv not found in data directory.
# Warning: file 01719_003_SN17_18bars_ssf.csv not found in data directory.
# Warning: file 01720_004_SN17_15bars_ssf.csv not found in data directory.
# Warning: file 01721_005_SN17_12bars_ssf.csv not found in data directory.
# Warning: file 01722_006_SN17_9bars_ssf.csv not found in data directory.
# Warning: file 01723_007_SN17_24bars_health_check.csv not found in data directory.
# Warning: file 01724_008_SN17_21bars_health_check.csv not found in data directory.
# Warning: file 01725_009_SN17_18bars_health_check.csv not found in data directory.
# Warning: file 01726_010_SN17_15bars_health_check.csv not found in data directory.
# Warning: file 01727_011_SN17_12bars_health_check.csv not found in data directory.
# Warning: file 01728_012_SN17_9bars_health_check.csv not found in data directory.
# Warning: file 01729_013_SN17_24bars_ramp1.csv not found in data directory.
# Warning: file 01730_014_SN17_24bars_ramp2.csv not found in data directory.
# Warning: file 01731_015_SN17_24bars_ramp3.csv not found in data directory.
# Warning: file 01732_016_SN17_24bars_ramp4.csv not found in data directory.
# Warning: file 01733_017_SN17_24bars_onmod.csv not found in data directory.
# Warning: file 01734_018_SN17_24bars_offmod.csv not found in data directory.
# Warning: file 01735_019_SN17_24bars_random_short.csv not found in data directory.
# Warning: file 01736_020_SN17_24bars_random_long.csv not found in data directory.
# Warning: file 01737_021_SN17_24bars_random_mixed.csv not found in data directory.
# Warning: file 01738_022_SN17_21bars_ramp1.csv not found in data directory.
# Warning: file 01739_023_SN17_21bars_ramp2.csv not found in data directory.
# Warning: file 01740_024_SN17_21bars_ramp3.csv not found in data directory.
# Warning: file 01741_025_SN17_21bars_ramp4.csv not found in data directory.
# Warning: file 01742_026_SN17_21bars_onmod.csv not found in data directory.
# Warning: file 01743_027_SN17_21bars_offmod.csv not found in data directory.
# Warning: file 01744_028_SN17_21bars_random_short.csv not found in data directory.
# Warning: file 01745_029_SN17_21bars_random_long.csv not found in data directory.
# Warning: file 01746_030_SN17_21bars_random_mixed.csv not found in data directory.
# Warning: file 01747_031_SN17_18bars_ramp1.csv not found in data directory.
# Warning: file 01748_032_SN17_18bars_ramp2.csv not found in data directory.
# Warning: file 01749_033_SN17_18bars_ramp3.csv not found in data directory.
# Warning: file 01750_034_SN17_18bars_ramp4.csv not found in data directory.
# Warning: file 01751_035_SN17_18bars_onmod.csv not found in data directory.
# Warning: file 01752_036_SN17_18bars_offmod.csv not found in data directory.
# Warning: file 01753_037_SN17_18bars_random_short.csv not found in data directory.
# Warning: file 01754_038_SN17_18bars_random_long.csv not found in data directory.
# Warning: file 01755_039_SN17_18bars_random_mixed.csv not found in data directory.
# Warning: file 01756_040_SN17_24bars_ssf.csv not found in data directory.
# Warning: file 01757_041_SN17_21bars_ssf.csv not found in data directory.
# Warning: file 01758_042_SN17_18bars_ssf.csv not found in data directory.
# Warning: file 01759_043_SN17_15bars_ssf.csv not found in data directory.
# Warning: file 01760_044_SN17_12bars_ssf.csv not found in data directory.
# Warning: file 01761_045_SN17_9bars_ssf.csv not found in data directory.
# Warning: file 01762_046_SN17_24bars_health_check.csv not found in data directory.
# Warning: file 01763_047_SN17_21bars_health_check.csv not found in data directory.
# Warning: file 01764_048_SN17_18bars_health_check.csv not found in data directory.
# Warning: file 01765_049_SN17_15bars_health_check.csv not found in data directory.
# Warning: file 01766_050_SN17_12bars_health_check.csv not found in data directory.
# Warning: file 01767_051_SN17_9bars_health_check.csv not found in data directory.
# Warning: file 01768_052_SN17_15bars_ramp1.csv not found in data directory.
# Warning: file 01769_053_SN17_15bars_ramp2.csv not found in data directory.
# Warning: file 01770_054_SN17_15bars_ramp3.csv not found in data directory.
# Warning: file 01771_055_SN17_15bars_ramp4.csv not found in data directory.
# Warning: file 01772_056_SN17_15bars_onmod.csv not found in data directory.
# Warning: file 01773_057_SN17_15bars_offmod.csv not found in data directory.
# Warning: file 01774_058_SN17_15bars_random_short.csv not found in data directory.
# Warning: file 01775_059_SN17_15bars_random_long.csv not found in data directory.
# Warning: file 01776_060_SN17_15bars_random_mixed.csv not found in data directory.
# Warning: file 01777_061_SN17_12bars_ramp1.csv not found in data directory.
# Warning: file 01778_062_SN17_12bars_ramp2.csv not found in data directory.
# Warning: file 01779_063_SN17_12bars_ramp3.csv not found in data directory.
# Warning: file 01780_064_SN17_12bars_ramp4.csv not found in data directory.
# Warning: file 01781_065_SN17_12bars_onmod.csv not found in data directory.
# Warning: file 01782_066_SN17_12bars_offmod.csv not found in data directory.
# Warning: file 01783_067_SN17_12bars_random_short.csv not found in data directory.
# Warning: file 01784_068_SN17_12bars_random_long.csv not found in data directory.
# Warning: file 01785_069_SN17_12bars_random_mixed.csv not found in data directory.
# Warning: file 01786_070_SN17_9bars_ramp1.csv not found in data directory.
# Warning: file 01787_071_SN17_9bars_ramp2.csv not found in data directory.
# Warning: file 01788_072_SN17_9bars_ramp3.csv not found in data directory.
# Warning: file 01789_073_SN17_9bars_ramp4.csv not found in data directory.
# Warning: file 01790_074_SN17_9bars_onmod.csv not found in data directory.
# Warning: file 01791_075_SN17_9bars_offmod.csv not found in data directory.
# Warning: file 01792_076_SN17_9bars_random_short.csv not found in data directory.
# Warning: file 01793_077_SN17_9bars_random_long.csv not found in data directory.
# Warning: file 01794_078_SN17_9bars_random_mixed.csv not found in data directory.
# Warning: file 01795_079_SN17_24bars_ssf.csv not found in data directory.
# Warning: file 01796_080_SN17_21bars_ssf.csv not found in data directory.
# Warning: file 01797_081_SN17_18bars_ssf.csv not found in data directory.
# Warning: file 01798_082_SN17_15bars_ssf.csv not found in data directory.
# Warning: file 01799_083_SN17_12bars_ssf.csv not found in data directory.
# Warning: file 01800_084_SN17_9bars_ssf.csv not found in data directory.
# Warning: file 01801_085_SN17_24bars_health_check.csv not found in data directory.
# Warning: file 01802_086_SN17_21bars_health_check.csv not found in data directory.
# Warning: file 01803_087_SN17_18bars_health_check.csv not found in data directory.
# Warning: file 01804_088_SN17_15bars_health_check.csv not found in data directory.
# Warning: file 01805_089_SN17_12bars_health_check.csv not found in data directory.
# Warning: file 01806_090_SN17_9bars_health_check.csv not found in data directory.
# Warning: file 01807_091_SN17_7bars_ssf.csv not found in data directory.
# Warning: file 01808_092_SN17_5bars_ssf.csv not found in data directory.
# Warning: file 01809_093_SN17_7bars_health_check.csv not found in data directory.
# Warning: file 01810_094_SN17_5bars_health_check.csv not found in data directory.
# Warning: file 01811_095_SN17_7bars_ramp1.csv not found in data directory.
# Warning: file 01812_096_SN17_7bars_ramp2.csv not found in data directory.
# Warning: file 01813_097_SN17_7bars_ramp3.csv not found in data directory.
# Warning: file 01814_098_SN17_7bars_ramp4.csv not found in data directory.
# Warning: file 01815_099_SN17_7bars_onmod.csv not found in data directory.
# Warning: file 01816_100_SN17_7bars_offmod.csv not found in data directory.
# Warning: file 01817_101_SN17_7bars_random_short.csv not found in data directory.
# Warning: file 01818_102_SN17_7bars_random_long.csv not found in data directory.
# Warning: file 01819_103_SN17_7bars_random_mixed.csv not found in data directory.
# Warning: file 01820_104_SN17_5bars_ramp1.csv not found in data directory.
# Warning: file 01821_105_SN17_5bars_ramp2.csv not found in data directory.
# Warning: file 01822_106_SN17_5bars_ramp3.csv not found in data directory.
# Warning: file 01823_107_SN17_5bars_ramp4.csv not found in data directory.
# Warning: file 01824_108_SN17_5bars_onmod.csv not found in data directory.
# Warning: file 01825_109_SN17_5bars_offmod.csv not found in data directory.
# Warning: file 01826_110_SN17_5bars_random_short.csv not found in data directory.
# Warning: file 01827_111_SN17_5bars_random_long.csv not found in data directory.
# Warning: file 01828_112_SN17_5bars_random_mixed.csv not found in data directory.
# Warning: file 01829_001_SN18_24bars_ssf.csv not found in data directory.
# Warning: file 01830_002_SN18_21bars_ssf.csv not found in data directory.
# Warning: file 01831_003_SN18_18bars_ssf.csv not found in data directory.
# Warning: file 01832_004_SN18_15bars_ssf.csv not found in data directory.
# Warning: file 01833_005_SN18_12bars_ssf.csv not found in data directory.
# Warning: file 01834_006_SN18_9bars_ssf.csv not found in data directory.
# Warning: file 01835_007_SN18_24bars_health_check.csv not found in data directory.
# Warning: file 01836_008_SN18_21bars_health_check.csv not found in data directory.
# Warning: file 01837_009_SN18_18bars_health_check.csv not found in data directory.
# Warning: file 01838_010_SN18_15bars_health_check.csv not found in data directory.
# Warning: file 01839_011_SN18_12bars_health_check.csv not found in data directory.
# Warning: file 01840_012_SN18_9bars_health_check.csv not found in data directory.
# Warning: file 01841_013_SN18_24bars_ramp1.csv not found in data directory.
# Warning: file 01842_014_SN18_24bars_ramp2.csv not found in data directory.
# Warning: file 01843_015_SN18_24bars_ramp3.csv not found in data directory.
# Warning: file 01844_016_SN18_24bars_ramp4.csv not found in data directory.
# Warning: file 01845_017_SN18_24bars_onmod.csv not found in data directory.
# Warning: file 01846_018_SN18_24bars_offmod.csv not found in data directory.
# Warning: file 01847_019_SN18_24bars_random_short.csv not found in data directory.
# ...
# Warning: file 02416_028_SN23_21bars_random_short.csv not found in data directory.
# Warning: file 02417_029_SN23_21bars_random_long.csv not found in data directory.
# Warning: file 02418_030_SN23_21bars_random_mixed.csv not found in data directory.
# Warning: file 02419_031_SN23_18bars_ramp1.csv not found in data directory.
# Warning: file 02420_032_SN23_18bars_ramp2.csv not found in data directory.
# Warning: file 02421_033_SN23_18bars_ramp3.csv not found in data directory.
# Warning: file 02422_034_SN23_18bars_ramp4.csv not found in data directory.
# Warning: file 02423_035_SN23_18bars_onmod.csv not found in data directory.
# Warning: file 02424_036_SN23_18bars_offmod.csv not found in data directory.
# Warning: file 02425_037_SN23_18bars_random_short.csv not found in data directory.
# Warning: file 02426_038_SN23_18bars_random_long.csv not found in data directory.
# Warning: file 02427_039_SN23_18bars_random_mixed.csv not found in data directory.
# Warning: file 02428_040_SN23_24bars_ssf.csv not found in data directory.
# Warning: file 02429_041_SN23_21bars_ssf.csv not found in data directory.
# Warning: file 02430_042_SN23_18bars_ssf.csv not found in data directory.
# Warning: file 02431_043_SN23_15bars_ssf.csv not found in data directory.
# Warning: file 02432_044_SN23_12bars_ssf.csv not found in data directory.
# Warning: file 02433_045_SN23_9bars_ssf.csv not found in data directory.
# Warning: file 02434_046_SN23_24bars_health_check.csv not found in data directory.
# Warning: file 02435_047_SN23_21bars_health_check.csv not found in data directory.
# Warning: file 02436_048_SN23_18bars_health_check.csv not found in data directory.
# Warning: file 02437_049_SN23_15bars_health_check.csv not found in data directory.
# Warning: file 02438_050_SN23_12bars_health_check.csv not found in data directory.
# Warning: file 02439_051_SN23_9bars_health_check.csv not found in data directory.
# Warning: file 02440_052_SN23_15bars_ramp1.csv not found in data directory.
# Warning: file 02441_053_SN23_15bars_ramp2.csv not found in data directory.
# Warning: file 02442_054_SN23_15bars_ramp3.csv not found in data directory.
# Warning: file 02443_055_SN23_15bars_ramp4.csv not found in data directory.
# Warning: file 02444_056_SN23_15bars_onmod.csv not found in data directory.
# Warning: file 02445_057_SN23_15bars_offmod.csv not found in data directory.
# Warning: file 02446_058_SN23_15bars_random_short.csv not found in data directory.
# Warning: file 02447_059_SN23_15bars_random_long.csv not found in data directory.
# Warning: file 02448_060_SN23_15bars_random_mixed.csv not found in data directory.
# Warning: file 02449_061_SN23_12bars_ramp1.csv not found in data directory.
# Warning: file 02450_062_SN23_12bars_ramp2.csv not found in data directory.
# Warning: file 02451_063_SN23_12bars_ramp3.csv not found in data directory.
# Warning: file 02452_064_SN23_12bars_ramp4.csv not found in data directory.
# Warning: file 02453_065_SN23_12bars_onmod.csv not found in data directory.
# Warning: file 02454_066_SN23_12bars_offmod.csv not found in data directory.
# Warning: file 02455_067_SN23_12bars_random_short.csv not found in data directory.
# Warning: file 02456_068_SN23_12bars_random_long.csv not found in data directory.
# Warning: file 02457_069_SN23_12bars_random_mixed.csv not found in data directory.
# Warning: file 02458_070_SN23_9bars_ramp1.csv not found in data directory.
# Warning: file 02459_071_SN23_9bars_ramp2.csv not found in data directory.
# Warning: file 02460_072_SN23_9bars_ramp3.csv not found in data directory.
# Warning: file 02461_073_SN23_9bars_ramp4.csv not found in data directory.
# Warning: file 02462_074_SN23_9bars_onmod.csv not found in data directory.
# Warning: file 02463_075_SN23_9bars_offmod.csv not found in data directory.
# Warning: file 02464_076_SN23_9bars_random_short.csv not found in data directory.
# Warning: file 02465_077_SN23_9bars_random_long.csv not found in data directory.
# Warning: file 02466_078_SN23_9bars_random_mixed.csv not found in data directory.
# Warning: file 02467_079_SN23_24bars_ssf.csv not found in data directory.
# Warning: file 02468_080_SN23_21bars_ssf.csv not found in data directory.
# Warning: file 02469_081_SN23_18bars_ssf.csv not found in data directory.
# Warning: file 02470_082_SN23_15bars_ssf.csv not found in data directory.
# Warning: file 02471_083_SN23_12bars_ssf.csv not found in data directory.
# Warning: file 02472_084_SN23_9bars_ssf.csv not found in data directory.
# Warning: file 02473_085_SN23_24bars_health_check.csv not found in data directory.
# Warning: file 02474_086_SN23_21bars_health_check.csv not found in data directory.
# Warning: file 02475_087_SN23_18bars_health_check.csv not found in data directory.
# Warning: file 02476_088_SN23_15bars_health_check.csv not found in data directory.
# Warning: file 02477_089_SN23_12bars_health_check.csv not found in data directory.
# Warning: file 02478_090_SN23_9bars_health_check.csv not found in data directory.
# Warning: file 02479_091_SN23_7bars_ssf.csv not found in data directory.
# Warning: file 02480_092_SN23_5bars_ssf.csv not found in data directory.
# Warning: file 02481_093_SN23_7bars_health_check.csv not found in data directory.
# Warning: file 02482_094_SN23_5bars_health_check.csv not found in data directory.
# Warning: file 02483_095_SN23_7bars_ramp1.csv not found in data directory.
# Warning: file 02484_096_SN23_7bars_ramp2.csv not found in data directory.
# Warning: file 02485_097_SN23_7bars_ramp3.csv not found in data directory.
# Warning: file 02486_098_SN23_7bars_ramp4.csv not found in data directory.
# Warning: file 02487_099_SN23_7bars_onmod.csv not found in data directory.
# Warning: file 02488_100_SN23_7bars_offmod.csv not found in data directory.
# Warning: file 02489_101_SN23_7bars_random_short.csv not found in data directory.
# Warning: file 02490_102_SN23_7bars_random_long.csv not found in data directory.
# Warning: file 02491_103_SN23_7bars_random_mixed.csv not found in data directory.
# Warning: file 02492_104_SN23_5bars_ramp1.csv not found in data directory.
# Warning: file 02493_105_SN23_5bars_ramp2.csv not found in data directory.
# Warning: file 02494_106_SN23_5bars_ramp3.csv not found in data directory.
# Warning: file 02495_107_SN23_5bars_ramp4.csv not found in data directory.
# Warning: file 02496_108_SN23_5bars_onmod.csv not found in data directory.
# Warning: file 02497_109_SN23_5bars_offmod.csv not found in data directory.
# Warning: file 02498_110_SN23_5bars_random_short.csv not found in data directory.
# Warning: file 02499_111_SN23_5bars_random_long.csv not found in data directory.
# Warning: file 02500_112_SN23_5bars_random_mixed.csv not found in data directory.
# Warning: file 02501_001_SN24_24bars_ssf.csv not found in data directory.
# Warning: file 02502_002_SN24_21bars_ssf.csv not found in data directory.
# Warning: file 02503_003_SN24_18bars_ssf.csv not found in data directory.
# Warning: file 02504_004_SN24_15bars_ssf.csv not found in data directory.
# Warning: file 02505_005_SN24_12bars_ssf.csv not found in data directory.
# Warning: file 02506_006_SN24_9bars_ssf.csv not found in data directory.
# Warning: file 02507_007_SN24_24bars_health_check.csv not found in data directory.
# Warning: file 02508_008_SN24_21bars_health_check.csv not found in data directory.
# Warning: file 02509_009_SN24_18bars_health_check.csv not found in data directory.
# Warning: file 02510_010_SN24_15bars_health_check.csv not found in data directory.
# Warning: file 02511_011_SN24_12bars_health_check.csv not found in data directory.
# Warning: file 02512_012_SN24_9bars_health_check.csv not found in data directory.
# Warning: file 02513_013_SN24_24bars_ramp1.csv not found in data directory.
# Warning: file 02514_014_SN24_24bars_ramp2.csv not found in data directory.
# Warning: file 02515_015_SN24_24bars_ramp3.csv not found in data directory.
# Warning: file 02516_016_SN24_24bars_ramp4.csv not found in data directory.
# Warning: file 02517_017_SN24_24bars_onmod.csv not found in data directory.
# Warning: file 02518_018_SN24_24bars_offmod.csv not found in data directory.
# Warning: file 02519_019_SN24_24bars_random_short.csv not found in data directory.
# Warning: file 02520_020_SN24_24bars_random_long.csv not found in data directory.
# Warning: file 02521_021_SN24_24bars_random_mixed.csv not found in data directory.
# Warning: file 02522_022_SN24_21bars_ramp1.csv not found in data directory.
# Warning: file 02523_023_SN24_21bars_ramp2.csv not found in data directory.
# Warning: file 02524_024_SN24_21bars_ramp3.csv not found in data directory.
# Warning: file 02525_025_SN24_21bars_ramp4.csv not found in data directory.
# Warning: file 02526_026_SN24_21bars_onmod.csv not found in data directory.
# Warning: file 02527_027_SN24_21bars_offmod.csv not found in data directory.
# Warning: file 02528_028_SN24_21bars_random_short.csv not found in data directory.
# Warning: file 02529_029_SN24_21bars_random_long.csv not found in data directory.
# Warning: file 02530_030_SN24_21bars_random_mixed.csv not found in data directory.
# Warning: file 02531_031_SN24_18bars_ramp1.csv not found in data directory.
# Warning: file 02532_032_SN24_18bars_ramp2.csv not found in data directory.
# Warning: file 02533_033_SN24_18bars_ramp3.csv not found in data directory.
# Warning: file 02534_034_SN24_18bars_ramp4.csv not found in data directory.
# Warning: file 02535_035_SN24_18bars_onmod.csv not found in data directory.
# Warning: file 02536_036_SN24_18bars_offmod.csv not found in data directory.
# Warning: file 02537_037_SN24_18bars_random_short.csv not found in data directory.
# Warning: file 02538_038_SN24_18bars_random_long.csv not found in data directory.
# Warning: file 02539_039_SN24_18bars_random_mixed.csv not found in data directory.
# Warning: file 02540_040_SN24_24bars_ssf.csv not found in data directory.
# Warning: file 02541_041_SN24_21bars_ssf.csv not found in data directory.
# Warning: file 02542_042_SN24_18bars_ssf.csv not found in data directory.
# Warning: file 02543_043_SN24_15bars_ssf.csv not found in data directory.
# Warning: file 02544_044_SN24_12bars_ssf.csv not found in data directory.
# Warning: file 02545_045_SN24_9bars_ssf.csv not found in data directory.
# Warning: file 02546_046_SN24_24bars_health_check.csv not found in data directory.
# Warning: file 02547_047_SN24_21bars_health_check.csv not found in data directory.
# Warning: file 02548_048_SN24_18bars_health_check.csv not found in data directory.
# Warning: file 02549_049_SN24_15bars_health_check.csv not found in data directory.
# Warning: file 02550_050_SN24_12bars_health_check.csv not found in data directory.
# Warning: file 02551_051_SN24_9bars_health_check.csv not found in data directory.
# Warning: file 02552_052_SN24_15bars_ramp1.csv not found in data directory.
# Warning: file 02553_053_SN24_15bars_ramp2.csv not found in data directory.
# Warning: file 02554_054_SN24_15bars_ramp3.csv not found in data directory.
# Warning: file 02555_055_SN24_15bars_ramp4.csv not found in data directory.
# Warning: file 02556_056_SN24_15bars_onmod.csv not found in data directory.
# Warning: file 02557_057_SN24_15bars_offmod.csv not found in data directory.
# Warning: file 02558_058_SN24_15bars_random_short.csv not found in data directory.
# Warning: file 02559_059_SN24_15bars_random_long.csv not found in data directory.
# Warning: file 02560_060_SN24_15bars_random_mixed.csv not found in data directory.
# Warning: file 02561_061_SN24_12bars_ramp1.csv not found in data directory.
# Warning: file 02562_062_SN24_12bars_ramp2.csv not found in data directory.
# Warning: file 02563_063_SN24_12bars_ramp3.csv not found in data directory.
# Warning: file 02564_064_SN24_12bars_ramp4.csv not found in data directory.
# Warning: file 02565_065_SN24_12bars_onmod.csv not found in data directory.
# Warning: file 02566_066_SN24_12bars_offmod.csv not found in data directory.
# Warning: file 02567_067_SN24_12bars_random_short.csv not found in data directory.
# Warning: file 02568_068_SN24_12bars_random_long.csv not found in data directory.
# Warning: file 02569_069_SN24_12bars_random_mixed.csv not found in data directory.
# Warning: file 02570_070_SN24_9bars_ramp1.csv not found in data directory.
# Warning: file 02571_071_SN24_9bars_ramp2.csv not found in data directory.
# Warning: file 02572_072_SN24_9bars_ramp3.csv not found in data directory.
# Warning: file 02573_073_SN24_9bars_ramp4.csv not found in data directory.
# Warning: file 02574_074_SN24_9bars_onmod.csv not found in data directory.
# Warning: file 02575_075_SN24_9bars_offmod.csv not found in data directory.
# Warning: file 02576_076_SN24_9bars_random_short.csv not found in data directory.
# Warning: file 02577_077_SN24_9bars_random_long.csv not found in data directory.
# Warning: file 02578_078_SN24_9bars_random_mixed.csv not found in data directory.
# Warning: file 02579_079_SN24_24bars_ssf.csv not found in data directory.
# Warning: file 02580_080_SN24_21bars_ssf.csv not found in data directory.
# Warning: file 02581_081_SN24_18bars_ssf.csv not found in data directory.
# Warning: file 02582_082_SN24_15bars_ssf.csv not found in data directory.
# Warning: file 02583_083_SN24_12bars_ssf.csv not found in data directory.
# Warning: file 02584_084_SN24_9bars_ssf.csv not found in data directory.
# Warning: file 02585_085_SN24_24bars_health_check.csv not found in data directory.
# Warning: file 02586_086_SN24_21bars_health_check.csv not found in data directory.
# Warning: file 02587_087_SN24_18bars_health_check.csv not found in data directory.
# Warning: file 02588_088_SN24_15bars_health_check.csv not found in data directory.
# Warning: file 02589_089_SN24_12bars_health_check.csv not found in data directory.
# Warning: file 02590_090_SN24_9bars_health_check.csv not found in data directory.
# Warning: file 02591_091_SN24_7bars_ssf.csv not found in data directory.
# Warning: file 02592_092_SN24_5bars_ssf.csv not found in data directory.
# Warning: file 02593_093_SN24_7bars_health_check.csv not found in data directory.
# Warning: file 02594_094_SN24_5bars_health_check.csv not found in data directory.
# Warning: file 02595_095_SN24_7bars_ramp1.csv not found in data directory.
# Warning: file 02596_096_SN24_7bars_ramp2.csv not found in data directory.
# Warning: file 02597_097_SN24_7bars_ramp3.csv not found in data directory.
# Warning: file 02598_098_SN24_7bars_ramp4.csv not found in data directory.
# Warning: file 02599_099_SN24_7bars_onmod.csv not found in data directory.
# Warning: file 02600_100_SN24_7bars_offmod.csv not found in data directory.
# Warning: file 02601_101_SN24_7bars_random_short.csv not found in data directory.
# Warning: file 02602_102_SN24_7bars_random_long.csv not found in data directory.
# Warning: file 02603_103_SN24_7bars_random_mixed.csv not found in data directory.
# Warning: file 02604_104_SN24_5bars_ramp1.csv not found in data directory.
# Warning: file 02605_105_SN24_5bars_ramp2.csv not found in data directory.
# Warning: file 02606_106_SN24_5bars_ramp3.csv not found in data directory.
# Warning: file 02607_107_SN24_5bars_ramp4.csv not found in data directory.
# Warning: file 02608_108_SN24_5bars_onmod.csv not found in data directory.
# Warning: file 02609_109_SN24_5bars_offmod.csv not found in data directory.
# Warning: file 02610_110_SN24_5bars_random_short.csv not found in data directory.
# Warning: file 02611_111_SN24_5bars_random_long.csv not found in data directory.
# Warning: file 02612_112_SN24_5bars_random_mixed.csv not found in data directory.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2464701266.py in <cell line: 0>()
#      68 all_normal_data = []
#      69 for f in normal_files:
# ---> 70     all_normal_data.append(data_dict[f][FEATURES].values)
#      71 all_normal_data = np.vstack(all_normal_data)
#      72 scaler = StandardScaler()
#
# KeyError: '01270_002_SN13_21bars_ssf.csv'
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cp -r /root/.cache/kagglehub/datasets/patrickfleith/spacecraft-thruster-firing-tests-dataset/versions/1 /content/drive/MyDrive/

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("patrickfleith/spacecraft-thruster-firing-tests-dataset")

print("Path to dataset files:", path)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Downloading from https://www.kaggle.com/api/v1/datasets/download/patrickfleith/spacecraft-thruster-firing-tests-dataset?dataset_version_number=1...
# 100%|██████████| 2.97G/2.97G [00:51<00:00, 62.5MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/patrickfleith/spacecraft-thruster-firing-tests-dataset/versions/1

# %%
pwd
# Out:
# '/content'

# %%
ls pwd
# Out:
# ls: cannot access 'pwd': No such file or directory

# %%
ls /content
# Out:
# drive/  DRL2.py  sample_data/

# %%
cp -r /root/.cache/kagglehub/datasets/patrickfleith/spacecraft-thruster-firing-tests-dataset/versions/1 /content/drive/MyDrive/

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("patrickfleith/spacecraft-thruster-firing-tests-dataset")

print("Path to dataset files:", path)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Downloading from https://www.kaggle.com/api/v1/datasets/download/patrickfleith/spacecraft-thruster-firing-tests-dataset?dataset_version_number=1...
# 100%|██████████| 2.97G/2.97G [00:51<00:00, 62.5MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/patrickfleith/spacecraft-thruster-firing-tests-dataset/versions/1

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("patrickfleith/spacecraft-thruster-firing-tests-dataset")

print("Path to dataset files:", path)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Downloading from https://www.kaggle.com/api/v1/datasets/download/patrickfleith/spacecraft-thruster-firing-tests-dataset?dataset_version_number=1...
# 100%|██████████| 2.97G/2.97G [00:51<00:00, 62.5MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/patrickfleith/spacecraft-thruster-firing-tests-dataset/versions/1
